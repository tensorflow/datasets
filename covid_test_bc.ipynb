# %%
import os
os.chdir('../root')

# %%
os.getcwd()
# Out:
# '/root'

# %%
# !git clone https://github.com/VishaalVenkatesh/datasets.git
# Out:
# Cloning into 'datasets'...
# remote: Enumerating objects: 53, done.
# remote: Counting objects: 100% (53/53), done.
# remote: Compressing objects: 100% (44/44), done.
# remote: Total 48338 (delta 29), reused 30 (delta 9), pack-reused 48285
# Receiving objects: 100% (48338/48338), 815.90 MiB | 35.75 MiB/s, done.
# Resolving deltas: 100% (34534/34534), done.
# Checking out files: 100% (6465/6465), done.

# %%
# !pip install importlib_resources
# Out:
# Collecting importlib_resources
#   Downloading https://files.pythonhosted.org/packages/ba/03/0f9595c0c2ef12590877f3c47e5f579759ce5caf817f8256d5dcbd8a1177/importlib_resources-3.0.0-py2.py3-none-any.whl
# Requirement already satisfied: zipp>=0.4; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from importlib_resources) (3.1.0)
# Installing collected packages: importlib-resources
# Successfully installed importlib-resources-3.0.0

# %%
os.chdir('datasets')

# %%
import tensorflow_datasets as tfds
import tensorflow as tf
import IPython.display as display

# %%
df_config_1 = tfds.load('covid_cxr/224')
# Out:
# Downloading and preparing dataset covid_cxr/224/2.0.0 (download: Unknown size, generated: Unknown size, total: Unknown size) to /root/tensorflow_datasets/covid_cxr/224/2.0.0...
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Dl Completed...', max=1.0, style=Progre…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Dl Size...', max=1.0, style=ProgressSty…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Shuffling and writing examples to /root/tensorflow_datasets/covid_cxr/224/2.0.0.incompleteKQO3ZM/covid_cxr-train.tfrecord
# HBox(children=(FloatProgress(value=0.0, max=13941.0), HTML(value='')))
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Shuffling and writing examples to /root/tensorflow_datasets/covid_cxr/224/2.0.0.incompleteKQO3ZM/covid_cxr-test.tfrecord
# HBox(children=(FloatProgress(value=0.0, max=1579.0), HTML(value='')))
# Dataset covid_cxr downloaded and prepared to /root/tensorflow_datasets/covid_cxr/224/2.0.0. Subsequent calls will reuse this data.

# %%
'''
    To print actual images with label
'''
# to read TFRecord file use TFRecordDataset
raw_image_dataset = tf.data.TFRecordDataset('/root/tensorflow_datasets/covid_cxr/224/2.0.0/covid_cxr-train.tfrecord-00001-of-00004')

# Create a dictionary describing the features.
image_feature_description = {
    "image": tf.io.FixedLenFeature([], tf.string), # tf.string means bytestring
    "label": tf.io.FixedLenFeature([], tf.int64),  # shape [] means single element
    }

# create a function to apply image feature description to each observation
def _parse_image_function(example_proto):
  # parse the input tf.Example proto using the dictionary above.
  return tf.io.parse_single_example(example_proto, image_feature_description)

# use map to apply this operation to each element of dataset
parsed_image_dataset = raw_image_dataset.map(_parse_image_function)

# %%
for image_features in parsed_image_dataset.take(5):
  image = image_features['image'].numpy()
  display.display(display.Image(data=image))
  label = image_features['label'].numpy()
  print('The label of image is', label)
# Out:
# The label of image is 1
# The label of image is 2
# The label of image is 2
# The label of image is 2
# The label of image is 1

# %%
df_config_2 = tfds.load('covid_cxr/480')
# Out:
# Downloading and preparing dataset covid_cxr/480/2.0.0 (download: Unknown size, generated: Unknown size, total: Unknown size) to /root/tensorflow_datasets/covid_cxr/480/2.0.0...
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Dl Completed...', max=1.0, style=Progre…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Dl Size...', max=1.0, style=ProgressSty…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Shuffling and writing examples to /root/tensorflow_datasets/covid_cxr/480/2.0.0.incompleteXZ1E0O/covid_cxr-train.tfrecord
# HBox(children=(FloatProgress(value=0.0, max=13941.0), HTML(value='')))
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Shuffling and writing examples to /root/tensorflow_datasets/covid_cxr/480/2.0.0.incompleteXZ1E0O/covid_cxr-test.tfrecord
# HBox(children=(FloatProgress(value=0.0, max=1579.0), HTML(value='')))
# Dataset covid_cxr downloaded and prepared to /root/tensorflow_datasets/covid_cxr/480/2.0.0. Subsequent calls will reuse this data.

# %%
'''
    To print actual images with label
'''
# to read TFRecord file use TFRecordDataset
raw_image_dataset = tf.data.TFRecordDataset('/root/tensorflow_datasets/covid_cxr/480/2.0.0/covid_cxr-train.tfrecord-00005-of-00016')

# Create a dictionary describing the features.
image_feature_description = {
    "image": tf.io.FixedLenFeature([], tf.string), # tf.string means bytestring
    "label": tf.io.FixedLenFeature([], tf.int64),  # shape [] means single element
    }

# create a function to apply image feature description to each observation
def _parse_image_function(example_proto):
  # parse the input tf.Example proto using the dictionary above.
  return tf.io.parse_single_example(example_proto, image_feature_description)

# use map to apply this operation to each element of dataset
parsed_image_dataset = raw_image_dataset.map(_parse_image_function)

# %%
for image_features in parsed_image_dataset.take(5):
  image = image_features['image'].numpy()
  display.display(display.Image(data=image))
  label = image_features['label'].numpy()
  print('The label of image is', label)
# Out:
# The label of image is 1
# The label of image is 1
# The label of image is 1
# The label of image is 2
# The label of image is 2

# %%
df_config_3 = tfds.load('covid_cxr/original')
# Out:
# Downloading and preparing dataset covid_cxr/original/2.0.0 (download: Unknown size, generated: Unknown size, total: Unknown size) to /root/tensorflow_datasets/covid_cxr/original/2.0.0...
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Dl Completed...', max=1.0, style=Progre…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Dl Size...', max=1.0, style=ProgressSty…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Shuffling and writing examples to /root/tensorflow_datasets/covid_cxr/original/2.0.0.incompleteHD549T/covid_cxr-train.tfrecord
# HBox(children=(FloatProgress(value=0.0, max=13941.0), HTML(value='')))
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Shuffling and writing examples to /root/tensorflow_datasets/covid_cxr/original/2.0.0.incompleteHD549T/covid_cxr-test.tfrecord
# HBox(children=(FloatProgress(value=0.0, max=1579.0), HTML(value='')))
# Dataset covid_cxr downloaded and prepared to /root/tensorflow_datasets/covid_cxr/original/2.0.0. Subsequent calls will reuse this data.

# %%
'''
    To print actual images with label
'''
# to read TFRecord file use TFRecordDataset
raw_image_dataset = tf.data.TFRecordDataset('/root/tensorflow_datasets/covid_cxr/original/2.0.0/covid_cxr-train.tfrecord-00005-of-00064')

# Create a dictionary describing the features.
image_feature_description = {
    "image": tf.io.FixedLenFeature([], tf.string), # tf.string means bytestring
    "label": tf.io.FixedLenFeature([], tf.int64),  # shape [] means single element
    }

# create a function to apply image feature description to each observation
def _parse_image_function(example_proto):
  # parse the input tf.Example proto using the dictionary above.
  return tf.io.parse_single_example(example_proto, image_feature_description)

# use map to apply this operation to each element of dataset
parsed_image_dataset = raw_image_dataset.map(_parse_image_function)

# %%
for image_features in parsed_image_dataset.take(5):
  image = image_features['image'].numpy()
  display.display(display.Image(data=image))
  label = image_features['label'].numpy()
  print('The label of image is', label)
# Out:
# The label of image is 1
# The label of image is 1
# The label of image is 1
# The label of image is 1
# The label of image is 2

# %%
😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍
