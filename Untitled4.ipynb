# %%
import tensorflow_datasets as tfds

# %%
df = tfds.load('covid_cxr_test')
# Out:
# ---------------------------------------------------------------------------
# DatasetNotFoundError                      Traceback (most recent call last)
# ~\datasets\tensorflow_datasets\core\utils\py_utils.py in try_reraise(*args, **kwargs)
#     413   try:
# --> 414     yield
#     415   except Exception:   # pylint: disable=broad-except
#
# ~\datasets\tensorflow_datasets\core\load.py in builder(name, **builder_init_kwargs)
#     178       prefix="Failed to construct dataset {}".format(name)):
# --> 179     return builder_cls(name)(**builder_kwargs)  # pytype: disable=not-instantiable
#     180
#
# ~\datasets\tensorflow_datasets\core\load.py in builder_cls(name)
#     143   if name not in registered._DATASET_REGISTRY:
# --> 144     raise DatasetNotFoundError(name)
#     145   return registered._DATASET_REGISTRY[name]
#
# DatasetNotFoundError: Dataset covid_cxr_test not found. Available datasets:
# 	- abstract_reasoning
# 	- aeslc
# 	- aflw2k3d
# 	- ag_news_subset
# 	- ai2_arc
# ...
