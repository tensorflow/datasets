# %%
import tensorflow_datasets as tfds
df = tfds.load('covid_cxr')
# Out:
# ...
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# ~\datasets\tensorflow_datasets\core\download\extractor.py in _sync_extract(self, from_path, method, to_path)
#      90         dst_path = path and os.path.join(to_path_tmp, path) or to_path_tmp
# ---> 91         _copy(handle, dst_path)
#      92     except BaseException as err:
#
# ~\datasets\tensorflow_datasets\core\download\extractor.py in _copy(src_file, dest_path)
#     120         break
# --> 121       dest_file.write(data)
#     122
#
# ~\Anaconda3_Mod\lib\site-packages\tensorflow_core\python\lib\io\file_io.py in write(self, file_content)
#     105     """Writes file_content to the file. Appends to the end of the file."""
# --> 106     self._prewrite_check()
#     107     pywrap_tensorflow.AppendToFile(
#
# ~\Anaconda3_Mod\lib\site-packages\tensorflow_core\python\lib\io\file_io.py in _prewrite_check(self)
# ...
